# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\prade\Downloads\archive (3)\housing.csv")

# %%
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09      23086.80050  1.059034e+06
# 1                             3.09      40173.07217  1.505891e+06
# 2                             5.13      36882.15940  1.058988e+06
# 3                             3.26      34310.24283  1.260617e+06
# 4                             4.23      26354.10947  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46      22837.36103  1.060194e+06
# 4996                          4.02      25616.11549  1.482618e+06
# 4997                          2.13      33266.14549  1.030730e+06
# 4998                          5.44      42625.62016  1.198657e+06
# 4999                          4.07      46501.28380  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
data['Price'].value_counts()
# Out:
# Price
# 1.298950e+06    1
# 1.059034e+06    1
# 1.505891e+06    1
# 1.058988e+06    1
# 1.260617e+06    1
#                ..
# 1.042814e+06    1
# 6.637324e+05    1
# 1.707046e+06    1
# 1.545155e+06    1
# 7.988695e+05    1
# Name: count, Length: 5000, dtype: int64

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928700  9.975771e+05
# 50%                        4.050000     36199.406690  1.232669e+06
# 75%                        4.490000     42861.290770  1.471210e+06
# max                        6.500000     69621.713380  2.469066e+06

# %%
data.hist(bins=50,figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'Avg. Area Income'}>,
#         <Axes: title={'center': 'Avg. Area House Age'}>],
#        [<Axes: title={'center': 'Avg. Area Number of Rooms'}>,
#         <Axes: title={'center': 'Avg. Area Number of Bedrooms'}>],
#        [<Axes: title={'center': 'Area Population'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
def shuffle_split(data,ratio):
    np.random.seed(42)
    indices=np.random.permutation(len(data))
    test_Size=int(len(data)*ratio)
    testIndices=indices[:test_Size]
    trainIndices=indices[test_Size:]
    return data.iloc[trainIndices],data.iloc[testIndices]

# %%
train,test=shuffle_split(data,0.2)

# %%
train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4227       66547.01645             5.846095                   6.847298
# 4676       53722.00860             6.401391                   7.787764
# 800        64838.49290             6.437157                   8.699544
# 3671       67097.09212             6.086754                   7.211963
# 4193       75245.46544             8.167820                   7.420100
# ...                ...                  ...                        ...
# 4426       76223.56126             6.371627                   5.342217
# 466        56685.01444             6.958045                   7.502115
# 3092       66195.33771             6.507971                   6.611861
# 3772       58694.51502             7.394768                   9.269453
# 860        61162.58025             5.896316                   7.880521
#
#       Avg. Area Number of Bedrooms  Area Population        Price  \
# 4227                          4.13      27850.82290  1094879.773
# 4676                          3.30      47649.22466  1300389.351
# 800                           4.02      32921.01007  1382172.294
# 3671                          3.05      27191.50688  1027427.862
# 4193                          3.42      37410.66993  1562887.225
# ...                            ...              ...          ...
# 4426                          2.42      30165.33745  1023943.775
# 466                           3.38      43322.16685  1223100.542
# 3092                          3.14      37288.92357  1318597.715
# 3772                          4.32      49960.97724  1708631.365
# 860                           6.04      36033.70143  1060897.689
#
#                                                 Address
# 4227  2288 Gary Square Apt. 812\nWest Jose, PR 78536...
# 4676                         USS Williams\nFPO AE 65283
# 800               Unit 2193 Box 7909\nDPO AA 47323-2101
# 3671  052 Thomas Square Apt. 034\nWrightmouth, OR 04272
# 4193  879 Martha Route Suite 031\nNew Nichole, VI 60708
# ...                                                 ...
# 4426  8456 Rodgers Burg Apt. 215\nSouth Michelle, NM...
# 466     8584 Darrell Groves\nBennettberg, SD 72404-6826
# 3092        8367 Manuel Road\nNathanfort, AS 36077-1481
# 3772                   Unit 7385 Box 9302\nDPO AP 21450
# 860      06275 Ross Mills Suite 054\nLisastad, DC 67330
#
# [4000 rows x 7 columns]

# %%
test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1501       61907.59335             7.017838                   6.440256
# 2586       57160.20224             6.893260                   6.921532
# 2653       70190.79644             6.745054                   6.662567
# 1055       69316.79689             6.300409                   7.873576
# 705        72991.48165             3.412866                   6.494081
# ...                ...                  ...                        ...
# 4711       77267.65626             3.939501                   8.342808
# 2313       75967.13508             5.939370                   6.111658
# 3214       81013.61529             7.149797                   7.239105
# 2732       86762.88286             6.530193                   5.106962
# 1926       67071.83062             4.935155                   7.632398
#
#       Avg. Area Number of Bedrooms  Area Population        Price  \
# 1501                          3.25      43828.94721  1339096.077
# 2586                          3.13      43467.14704  1251794.179
# 2653                          2.01      29215.13611  1340094.966
# 1055                          4.28      24448.21146  1431507.623
# 705                           2.48      50626.49543  1042373.524
# ...                            ...              ...          ...
# 4711                          6.09      22487.71207  1107031.246
# 2313                          2.32      38897.09158  1405505.244
# 3214                          5.44      45472.04945  1924155.582
# 2732                          2.09      47724.58136  1571253.531
# 1926                          5.04      32084.74340   883147.471
#
#                                                 Address
# 1501  7521 Gregory Meadows\nEast Johntown, CO 93230-...
# 2586  15828 Marshall Stravenue Suite 199\nEast Matth...
# 2653                          USNS Brandt\nFPO AE 72594
# 1055                   PSC 3490, Box 0556\nAPO AE 04921
# 705   0618 Richardson Mountain Apt. 253\nJasmineport...
# ...                                                 ...
# 4711                          USS Navarro\nFPO AP 70992
# 2313         6395 Bruce Passage\nNew Michelle, AL 72494
# 3214  44348 Perez Court Apt. 137\nEast Nataliemouth,...
# 2732  4856 Wilkinson Shores Suite 654\nPort Lucaston...
# 1926         2681 Simmons Meadows\nLake James, KY 17286
#
# [1000 rows x 7 columns]
